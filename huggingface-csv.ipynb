# %% [markdown]
# # Sentiment Analysis

# %% [markdown]
# # Identifying Most Reviewed Product from DataSet.
# We've dataset from amazon with reviews of many products, <br>out of them we need to know which are the most reviewed products?<br>
# Let's look at dataset and see how we can do this!

# %%
# Importing the libraries
import pandas as pd

# Importing the dataset
df=pd.read_csv("sentiment__dataset.csv", dtype='unicode')

# Shows the first five rows of a dataset
df.head()
# Out:
#                      id                                               name  \
# 0  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 1  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 2  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 3  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 4  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
#
#         asins   brand                                         categories  \
# 0  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 1  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 2  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 3  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 4  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
#
#                                                 keys manufacturer  \
# ...

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ### Data Lookup
# After looking at data from dataset, it's look like there are some NaN values in it which we don't require

# %%
# Number of rows and columns in a dataset
df.shape
# Out:
# (34660, 21)

# %%
# Number of different columns in a dataset
df.columns
# Out:
# Index(['id', 'name', 'asins', 'brand', 'categories', 'keys', 'manufacturer',
#        'reviews.date', 'reviews.dateAdded', 'reviews.dateSeen',
#        'reviews.didPurchase', 'reviews.doRecommend', 'reviews.id',
#        'reviews.numHelpful', 'reviews.rating', 'reviews.sourceURLs',
#        'reviews.text', 'reviews.title', 'reviews.userCity',
#        'reviews.userProvince', 'reviews.username'],
#       dtype='object')

# %%
# Shows the last five rows of a dataset
df.tail()
# Out:
#                          id name       asins   brand  \
# 34655  AVpfiBlyLJeJML43-4Tp  NaN  B006GWO5WK  Amazon
# 34656  AVpfiBlyLJeJML43-4Tp  NaN  B006GWO5WK  Amazon
# 34657  AVpfiBlyLJeJML43-4Tp  NaN  B006GWO5WK  Amazon
# 34658  AVpfiBlyLJeJML43-4Tp  NaN  B006GWO5WK  Amazon
# 34659  AVpfiBlyLJeJML43-4Tp  NaN  B006GWO5WK  Amazon
#
#                                               categories  \
# 34655  Computers/Tablets & Networking,Tablet & eBook ...
# 34656  Computers/Tablets & Networking,Tablet & eBook ...
# 34657  Computers/Tablets & Networking,Tablet & eBook ...
# 34658  Computers/Tablets & Networking,Tablet & eBook ...
# 34659  Computers/Tablets & Networking,Tablet & eBook ...
#
#                                                     keys  \
# 34655  newamazonkindlefirehd9wpowerfastadaptercharger...
# 34656  newamazonkindlefirehd9wpowerfastadaptercharger...
# 34657  newamazonkindlefirehd9wpowerfastadaptercharger...
# 34658  newamazonkindlefirehd9wpowerfastadaptercharger...
# ...

# %% [markdown]
# ## Changing Column Names
# As column names are lengthy and not informative, so we'll give some suitable names to them

# %%
df.columns = ['id', 'name', 'asins', 'brand', 'categories', 'keys', 'manufacturer','date', 'dateAdded', 'dateSeen','isPurchase', 'isRecommended', 'reviewsId','numHelpful', 'rating', 'sourceURLs','reviewText', 'reviewTitle', 'city','userProvince', 'username']
df.head()
# Out:
#                      id                                               name  \
# 0  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 1  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 2  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 3  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 4  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
#
#         asins   brand                                         categories  \
# 0  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 1  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 2  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 3  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 4  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
#
#                                                 keys manufacturer  \
# ...

# %% [markdown]
# ## Handling Null values

# %%
df.reviewsId.dtype
# Out:
# dtype('O')

# %%
df.dtypes
# Out:
# id               object
# name             object
# asins            object
# brand            object
# categories       object
# keys             object
# manufacturer     object
# date             object
# dateAdded        object
# dateSeen         object
# isPurchase       object
# isRecommended    object
# reviewsId        object
# numHelpful       object
# rating           object
# sourceURLs       object
# reviewText       object
# reviewTitle      object
# city             object
# userProvince     object
# username         object
# dtype: object

# %%
df.reviewsId.fillna(0.0)
df.head()
# Out:
#                      id                                               name  \
# 0  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 1  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 2  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 3  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 4  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
#
#         asins   brand                                         categories  \
# 0  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 1  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 2  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 3  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 4  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
#
#                                                 keys manufacturer  \
# ...

# %% [markdown]
# ## Removal of unnecessary columns
# To identify most reviewed products, we don't required few columns, therefore we'll remove those columns from dataset

# %%
df.columns
# Out:
# Index(['id', 'name', 'asins', 'brand', 'categories', 'keys', 'manufacturer',
#        'date', 'dateAdded', 'dateSeen', 'isPurchase', 'isRecommended',
#        'reviewsId', 'numHelpful', 'rating', 'sourceURLs', 'reviewText',
#        'reviewTitle', 'city', 'userProvince', 'username'],
#       dtype='object')

# %%
df=df.drop('keys',1)
df.drop('sourceURLs', 1, inplace=True)
df.drop(['dateAdded','dateSeen'], 1, inplace=True)
df.head()
# Out:
#                      id                                               name  \
# 0  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 1  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 2  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 3  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 4  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
#
#         asins   brand                                         categories  \
# 0  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 1  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 2  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 3  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 4  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
#
# ...

# %%
df.isPurchase.fillna(False,inplace=True)
df.reviewsId.fillna("",inplace=True)
df.city.fillna("",inplace=True)
df.userProvince.fillna("",inplace=True)
df.head()
# Out:
#                      id                                               name  \
# 0  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 1  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 2  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 3  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 4  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
#
#         asins   brand                                         categories  \
# 0  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 1  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 2  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 3  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 4  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
#
# ...

# %% [markdown]
# # DataSet Statistics

# %%
df.describe(include='object')
# Out:
#                           id  \
# count                  34660
# unique                    42
# top     AVphgVaX1cnluZ0-DR74
# freq                   10966
#
#                                                      name       asins   brand  \
# count                                               27900       34658   34660
# unique                                                 48          41       6
# top     Fire Tablet, 7 Display, Wi-Fi, 8 GB - Includes...  B018Y229OU  Amazon
# freq                                                10966       10966   28701
#
#                                                categories manufacturer  \
# count                                               34660        34660
# unique                                                 41            2
# top     Fire Tablets,Tablets,Computers & Tablets,All T...       Amazon
# freq                                                10966        34639
#
# ...

# %% [markdown]
# Removal of rows which are affecting our estimation

# %%
df.dropna(subset=['name'],inplace=True)
df.describe(include='object')
# Out:
#                           id  \
# count                  27900
# unique                    30
# top     AVphgVaX1cnluZ0-DR74
# freq                   10966
#
#                                                      name       asins   brand  \
# count                                               27900       27898   27900
# unique                                                 48          29       1
# top     Fire Tablet, 7 Display, Wi-Fi, 8 GB - Includes...  B018Y229OU  Amazon
# freq                                                10966       10966   27900
#
#                                                categories manufacturer  \
# count                                               27900        27900
# unique                                                 29            1
# top     Fire Tablets,Tablets,Computers & Tablets,All T...       Amazon
# freq                                                10966        27900
#
# ...

# %% [markdown]
# ## List of most reviewed product with number of reviews per product

# %%
df['name'].value_counts()
# Out:
# Fire Tablet, 7 Display, Wi-Fi, 8 GB - Includes Special Offers, Magenta                                                                                                                                            10966
# Echo (White),,,\nEcho (White),,,                                                                                                                                                                                   3309
# Amazon Kindle Paperwhite - eBook reader - 4 GB - 6 monochrome Paperwhite - touchscreen - Wi-Fi - black,,,                                                                                                          3176
# All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi, 16 GB - Includes Special Offers, Magenta                                                                                                                            2814
# ...

# %% [markdown]
# # **Let's do sentiment analysis on reviews of these products**

# %%
# Installing hugging face transformers
# !pip install git+https://github.com/huggingface/transformers.git
# Out:
# ...
#   Cloning https://github.com/huggingface/transformers.git to /tmp/pip-req-build-qy5wm6i0
#   Running command git clone -q https://github.com/huggingface/transformers.git /tmp/pip-req-build-qy5wm6i0
# ...
#      |████████████████████████████████| 3.0MB 2.7MB/s
# ...
#      |████████████████████████████████| 1.1MB 25.0MB/s
# ...
#      |████████████████████████████████| 890kB 35.0MB/s
# ...
#   Created wheel for transformers: filename=transformers-3.0.2-cp36-none-any.whl size=788410 sha256=7c38a4ff8e8863ee2f7b70652103643530eaeee4c96b4e4eb8bffbbdd3af0941
#   Stored in directory: /tmp/pip-ephem-wheel-cache-1qefgs3q/wheels/33/eb/3b/4bf5dd835e865e472d4fc0754f35ac0edb08fe852e8f21655f
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp36-none-any.whl size=893260 sha256=7658cd750aa874eae12aca1641893a5a4d521f64869d879df40e25fbc2d9b6fa
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
# Successfully built transformers sacremoses
# ...

# %% [markdown]
# # Let make all the review positive and negative based on their ratings. Negative(<3) and Positive(>=3)

# %%
sdf = df[['rating','reviewText']]
sdf.head(2)
# Out:
#   rating                                         reviewText
# 0      5  This product so far has not disappointed. My c...
# 1      5  great for beginner or experienced person. Boug...

# %%
def assign_sentiment(rating):
  if float(rating) >= 3:
    return "Positive"
  else:
    return "Negative"
sdf['sentiment'] = sdf['rating'].apply(assign_sentiment)
sdf.head(3)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rating                                         reviewText sentiment
# 0      5  This product so far has not disappointed. My c...  Positive
# 1      5  great for beginner or experienced person. Boug...  Positive
# 2      5  Inexpensive tablet for him to use and learn on...  Positive

# %%
sdf.drop('rating', inplace=True, axis=1)
sdf.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                                           reviewText sentiment
# 0  This product so far has not disappointed. My c...  Positive
# 1  great for beginner or experienced person. Boug...  Positive
# 2  Inexpensive tablet for him to use and learn on...  Positive
# 3  I've had my Fire HD 8 two weeks now and I love...  Positive
# 4  I bought this for my grand daughter when she c...  Positive

# %%
# from hugging face we are using sentiment analysis
from transformers import pipeline
sent_analysis = pipeline("sentiment-analysis")

# %%
sdf['reviewText'] = sdf['reviewText'].astype(str)
sdf.head()
sdf = sdf[sdf['reviewText'].map(len) <= 2000]
sdf.head()
sdf.dropna(inplace=True)
sdf.reset_index(inplace=True, drop=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
actual_sentiment = sdf['sentiment']

# %%
predicted_sentiment = []
for review in sdf['reviewText']:
  predicted_sentiment.append(sent_analysis(review)[0]['label'])

# %%
predicted_output = pd.DataFrame(predicted_sentiment)
predicted_output[0] = predicted_output[0].str.title()
predicted_output.head()
# Out:
#           0
# 0  Positive
# 1  Positive
# 2  Positive
# 3  Positive
# 4  Positive

# %%
actual_output = pd.DataFrame(actual_sentiment)
actual_output.head()
# Out:
#   sentiment
# 0  Positive
# 1  Positive
# 2  Positive
# 3  Positive
# 4  Positive

# %%
from sklearn.metrics import classification_report
print(classification_report(actual_output['sentiment'], predicted_output[0], target_names=['Negative Reviews','Positive Reviews']))
# Out:
#                   precision    recall  f1-score   support
#
# Negative Reviews       0.13      0.85      0.22       696
# Positive Reviews       1.00      0.85      0.92     27182
#
#         accuracy                           0.85     27878
#        macro avg       0.56      0.85      0.57     27878
#     weighted avg       0.97      0.85      0.90     27878
